# %%
import os
import requests
from datetime import datetime

from tqdm import tqdm_notebook as tqdm

import pandas as pd
import numpy as np

# %%
class DownloadCollegeFootballData(object):
    """
    Object to download data from college football data api

    """
    base_url = 'https://api.collegefootballdata.com/'

    years = [int(2018 + year) for year in range(int(pd.Timestamp(datetime.now()).year - 2018))]

    endpoints = {
        'games':  'games/',
        'stats': 'games/teams'
    }

    def download_games(self) -> pd.DataFrame:
        """
        Download Game Information (no stats) for a year
        """
        df = []
        for year in (self.years):
            print(year)
            # Return data
            r = requests.get(self.base_url + self.endpoints['games'], params={'year': year})

            # Convert to dataframe
            df_year = pd.DataFrame.from_records(r.json())

            # Only retain useful fields, rename as necessary
            df_year = df_year[
                ['id', 'season', 'week', 'season_type', 'home_team', 'away_team', 'home_points', 'away_points']
            ].rename(columns={'id': 'game_id'})

            # Gather
            df.append(df_year)
        df = pd.concat(df).reset_index(drop=True)

        return df

    def download_stats(self, df_games: pd.DataFrame = None) -> pd.DataFrame:
        """
        Download stats for each game
        """
        if df_games is None:
            df_games = self.download_games()
        assert 'game_id' in df_games.columns
        print('stats')
        df_stats, not_working = [], {}
        for game_id in set(df_games['game_id']):
            params = {'gameId': game_id}
            r = requests.get(self.base_url + self.endpoints['stats'], params=params)
            if r.status_code != 200:
                continue
            try: 
                stats_by_team = r.json()[0]['teams']
                df_game = []
                for team in stats_by_team:
                    df_game_long = pd.DataFrame.from_records(team['stats'])
                    df_game_long['category'] = team['homeAway'] + '_' + df_game_long['category']
                    df_game.append(df_game_long)
                df_game = pd.concat(df_game)
                # Pivot
                df_game = pd.pivot_table(df_game, columns='category', values='stat', aggfunc='first').reset_index(drop=True)
                df_stats.append(df_game.assign(game_id=game_id))
            except:
                not_working[game_id] = r.json()
        df_stats = pd.concat(df_stats).reset_index(drop=True)
        
        return df_stats, not_working

# %%
downloader = DownloadCollegeFootballData()

# %%
df_stats, didnt_work = downloader.download_stats()
# Out:
# 2018
# 2019
# stats

# %%
df_stats.shape
# Out:
# (1693, 71)

# %%
len(didnt_work)
# Out:
# 1

# %%
didnt_work
# Out:
# {401117539: []}

# %%
df_stats.head()
# Out:
#   away_completionAttempts away_defensiveTDs away_firstDowns  \
# 0                   16-29                 0              18
# 1                   22-47                 0              12
# 2                   19-29                 0              22
# 3                   24-37                 0              24
# 4                   12-24                 0               9
#
#   away_fourthDownEff away_fumblesLost away_fumblesRecovered  \
# 0                1-2                1                     0
# 1                0-5                0                     1
# 2                2-3                0                     2
# 3                0-0                0                     0
# 4                0-0                0                     0
#
#   away_interceptions away_kickReturnTDs away_kickReturnYards away_kickReturns  \
# 0                  0                  0                   31                3
# 1                  1                  0                   87                4
# 2                  3                  0                   57                3
# 3                  0                  0                   33                2
# 4                  1                  0                   66                3
#
#   away_kickingPoints away_netPassingYards away_passesDeflected  \
# 0                  4                  244                    5
# 1                  4                  296                    2
# 2                  6                  209                    2
# 3                  5                  272                    5
# 4                  1                  252                    3
#
#   away_passingTDs away_possessionTime away_qbHurries away_rushingAttempts  \
# 0               3               20:21              0                   28
# 1               1               22:33              1                   16
# 2               2               37:21              2                   48
# 3               2               31:48              4                   38
# 4               2               15:47              2                   19
#
#   away_rushingTDs away_rushingYards away_sacks away_tackles  \
# 0               1               140          0           47
# 1               0                -9          3           33
# 2               2               231          3           37
# 3               3               171          1           36
# 4               1                 4          2           57
#
#   away_tacklesForLoss away_thirdDownEff away_totalPenaltiesYards  \
# 0                   5              2-11                     6-60
# 1                   8              3-15                     6-30
# 2                   5              4-14                     6-55
# 3                   2              6-14                     7-62
# 4                  14              2-10                     4-40
#
#   away_totalYards away_turnovers away_yardsPerPass away_yardsPerRushAttempt  \
# 0             384              1               8.4                      5.0
# 1             287              1               6.3                     -0.6
# 2             440              3               7.2                      4.8
# 3             443              0               7.4                      4.5
# 4             256              1              10.5                      0.2
#
#   home_completionAttempts home_defensiveTDs home_firstDowns  \
# 0                   12-24                 0              22
# 1                   13-20                 1              20
# 2                   11-23                 0              15
# 3                   25-46                 0              23
# 4                   41-51                 2              34
#
#   home_fourthDownEff home_fumblesLost home_fumblesRecovered  \
# 0                1-1                0                     1
# 1                0-0                1                     0
# 2                4-5                2                     0
# 3                2-5                0                     0
# 4                2-3                0                     0
#
#   home_interceptions home_kickReturnTDs home_kickReturnYards home_kickReturns  \
# 0                  0                  0                  170                6
# 1                  0                  0                   43                3
# 2                  2                  0                  120                5
# 3                  0                  0                   50                2
# 4                  0                  1                  116                2
#
#   home_kickingPoints home_netPassingYards home_passesDeflected  \
# 0                 11                   87                    4
# 1                 10                  267                    8
# 2                  2                   91                    2
# 3                  4                  357                    2
# 4                 16                  461                    0
#
#   home_passingTDs home_possessionTime home_puntReturnTDs home_puntReturnYards  \
# 0               0               39:39                  0                   -1
# 1               1               37:27                  0                   20
# 2               1               22:39                NaN                  NaN
# 3               3               28:12                  0                   15
# 4               3               44:13                  0                    5
#
#   home_puntReturns home_qbHurries home_rushingAttempts home_rushingTDs  \
# 0                1              2                   50               3
# 1                2              7                   46               2
# 2              NaN              1                   43               3
# 3                2              3                   27               1
# 4                2              2                   43               0
#
#   home_rushingYards home_sacks home_tackles home_tacklesForLoss  \
# 0               310          3           33                   5
# 1               226          4           25                   4
# 2               217          3           42                   6
# 3                87          2           44                   5
# 4                68          4           18                   4
#
#   home_thirdDownEff home_totalFumbles home_totalPenaltiesYards  \
# 0              4-14                 0                     7-54
# 1              7-15                 1                     4-45
# 2              3-13                 3                     7-82
# 3              5-15                 1                     8-71
# 4              9-17                 1                     5-40
#
#   home_totalYards home_turnovers home_yardsPerPass home_yardsPerRushAttempt  \
# 0             397              0               3.6                      6.2
# 1             493              1              13.4                      4.9
# 2             308              4               4.0                      5.0
# 3             444              0               7.8                      3.2
# 4             529              0               9.0                      1.6
#
#      game_id away_totalFumbles home_interceptionTDs home_interceptionYards  \
# 0  401014972               NaN                  NaN                    NaN
# 1  401014973                 2                    1                     26
# 2  401014974                 2                    0                      1
# 3  401014975               NaN                  NaN                    NaN
# 4  401014976                 1                    1                     36
#
#   home_passesIntercepted away_interceptionTDs away_interceptionYards  \
# 0                    NaN                  NaN                    NaN
# 1                      1                  NaN                    NaN
# 2                      3                    0                     28
# 3                    NaN                  NaN                    NaN
# 4                      1                  NaN                    NaN
#
#   away_passesIntercepted away_puntReturnTDs away_puntReturnYards  \
# 0                    NaN                NaN                  NaN
# 1                    NaN                NaN                  NaN
# 2                      2                NaN                  NaN
# 3                    NaN                  0                   50
# 4                    NaN                  0                    8
#
#   away_puntReturns
# 0              NaN
# 1              NaN
# 2              NaN
# 3                2
# 4                1

# %%
teams
# Out:
# [{'school': 'LSU',
#   'conference': 'SEC',
#   'homeAway': 'home',
#   'points': 37,
#   'stats': [{'category': 'tacklesForLoss', 'stat': '4'},
#    {'category': 'defensiveTDs', 'stat': '0'},
#    {'category': 'tackles', 'stat': '31'},
#    {'category': 'sacks', 'stat': '3'},
#    {'category': 'qbHurries', 'stat': '1'},
#    {'category': 'passesDeflected', 'stat': '4'},
#    {'category': 'fumblesRecovered', 'stat': '0'},
#    {'category': 'rushingTDs', 'stat': '0'},
#    {'category': 'passingTDs', 'stat': '4'},
#    {'category': 'kickingPoints', 'stat': '13'},
#    {'category': 'interceptionYards', 'stat': '17'},
#    {'category': 'interceptionTDs', 'stat': '0'},
#    {'category': 'passesIntercepted', 'stat': '2'},
#    {'category': 'possessionTime', 'stat': '33:38'},
#    {'category': 'interceptions', 'stat': '0'},
#    {'category': 'fumblesLost', 'stat': '0'},
#    {'category': 'turnovers', 'stat': '0'},
#    {'category': 'totalPenaltiesYards', 'stat': '5-45'},
#    {'category': 'yardsPerRushAttempt', 'stat': '3.7'},
#    {'category': 'rushingAttempts', 'stat': '36'},
#    {'category': 'rushingYards', 'stat': '132'},
#    {'category': 'yardsPerPass', 'stat': '9.2'},
#    {'category': 'completionAttempts', 'stat': '28-38'},
#    {'category': 'netPassingYards', 'stat': '349'},
#    {'category': 'totalYards', 'stat': '481'},
#    {'category': 'fourthDownEff', 'stat': '0-0'},
#    {'category': 'thirdDownEff', 'stat': '9-16'},
#    {'category': 'firstDowns', 'stat': '26'}]},
#  {'school': 'Georgia',
#   'conference': 'SEC',
#   'homeAway': 'away',
#   'points': 10,
#   'stats': [{'category': 'tacklesForLoss', 'stat': '3'},
#    {'category': 'defensiveTDs', 'stat': '0'},
#    {'category': 'tackles', 'stat': '47'},
#    {'category': 'sacks', 'stat': '2'},
#    {'category': 'qbHurries', 'stat': '5'},
#    {'category': 'passesDeflected', 'stat': '3'},
#    {'category': 'fumblesRecovered', 'stat': '0'},
#    {'category': 'rushingTDs', 'stat': '0'},
#    {'category': 'passingTDs', 'stat': '1'},
#    {'category': 'kickingPoints', 'stat': '4'},
#    {'category': 'possessionTime', 'stat': '26:22'},
#    {'category': 'interceptions', 'stat': '2'},
#    {'category': 'fumblesLost', 'stat': '0'},
#    {'category': 'turnovers', 'stat': '2'},
#    {'category': 'totalPenaltiesYards', 'stat': '3-17'},
#    {'category': 'yardsPerRushAttempt', 'stat': '2.4'},
#    {'category': 'rushingAttempts', 'stat': '25'},
#    {'category': 'rushingYards', 'stat': '61'},
#    {'category': 'yardsPerPass', 'stat': '5.2'},
#    {'category': 'completionAttempts', 'stat': '20-43'},
#    {'category': 'netPassingYards', 'stat': '225'},
#    {'category': 'totalYards', 'stat': '286'},
#    {'category': 'fourthDownEff', 'stat': '3-3'},
#    {'category': 'thirdDownEff', 'stat': '3-13'},
#    {'category': 'firstDowns', 'stat': '20'}]}]

# %%
df_stats = []
for team in teams:
    df_stat = pd.DataFrame.from_records(team['stats'])
    df_stat['category'] = team['homeAway'] + '_' + df_stat['category']
    df_stats.append(df_stat)
df_stats = pd.concat(df_stats)

# %%
df_stats.head()
# Out:
#               category stat
# 0  home_tacklesForLoss    4
# 1    home_defensiveTDs    0
# 2         home_tackles   31
# 3           home_sacks    3
# 4       home_qbHurries    1

# %%
df_pivoted = pd.pivot_table(df_stats, columns='category', values='stat', aggfunc='first').reset_index(drop=True)
df_pivoted.head()
# Out:
# category away_completionAttempts away_defensiveTDs away_firstDowns  \
# 0                          20-43                 0              20
#
# category away_fourthDownEff away_fumblesLost away_fumblesRecovered  \
# 0                       3-3                0                     0
#
# category away_interceptions away_kickingPoints away_netPassingYards  \
# 0                         2                  4                  225
#
# category away_passesDeflected away_passingTDs away_possessionTime  \
# 0                           3               1               26:22
#
# category away_qbHurries away_rushingAttempts away_rushingTDs  \
# 0                     5                   25               0
#
# category away_rushingYards away_sacks away_tackles away_tacklesForLoss  \
# 0                       61          2           47                   3
#
# category away_thirdDownEff away_totalPenaltiesYards away_totalYards  \
# 0                     3-13                     3-17             286
#
# category away_turnovers away_yardsPerPass away_yardsPerRushAttempt  \
# 0                     2               5.2                      2.4
#
# category home_completionAttempts home_defensiveTDs home_firstDowns  \
# 0                          28-38                 0              26
#
# category home_fourthDownEff home_fumblesLost home_fumblesRecovered  \
# 0                       0-0                0                     0
#
# category home_interceptionTDs home_interceptionYards home_interceptions  \
# 0                           0                     17                  0
#
# category home_kickingPoints home_netPassingYards home_passesDeflected  \
# 0                        13                  349                    4
#
# category home_passesIntercepted home_passingTDs home_possessionTime  \
# 0                             2               4               33:38
#
# category home_qbHurries home_rushingAttempts home_rushingTDs  \
# 0                     1                   36               0
#
# category home_rushingYards home_sacks home_tackles home_tacklesForLoss  \
# 0                      132          3           31                   4
#
# category home_thirdDownEff home_totalPenaltiesYards home_totalYards  \
# 0                     9-16                     5-45             481
#
# category home_turnovers home_yardsPerPass home_yardsPerRushAttempt
# 0                     0               9.2                      3.7

# %%
df_pivoted.shape
# Out:
# (2, 28)

# %%
df_pivoted.columns
# Out:
# Index(['completionAttempts', 'defensiveTDs', 'firstDowns', 'fourthDownEff',
#        'fumblesLost', 'fumblesRecovered', 'interceptionTDs',
#        'interceptionYards', 'interceptions', 'kickingPoints',
#        'netPassingYards', 'passesDeflected', 'passesIntercepted', 'passingTDs',
#        'possessionTime', 'qbHurries', 'rushingAttempts', 'rushingTDs',
#        'rushingYards', 'sacks', 'tackles', 'tacklesForLoss', 'thirdDownEff',
#        'totalPenaltiesYards', 'totalYards', 'turnovers', 'yardsPerPass',
#        'yardsPerRushAttempt'],
#       dtype='object', name='category')
