# %%
import os
import requests
from datetime import datetime

from tqdm import tqdm_notebook as tqdm

import pandas as pd
pd.set_option('display.max_rows', 100)
import numpy as np

# %%
class DownloadCollegeFootballData(object):
    """
    Object to download data from college football data api

    """
    base_url = 'https://api.collegefootballdata.com/'

    years = [int(2000 + year) for year in range(int(pd.Timestamp(datetime.now()).year - 2000))]

    endpoints = {
        'games':  'games/',
        'stats': 'games/teams'
    }

    def download_games(self) -> pd.DataFrame:
        """
        Download Game Information (no stats) for a year
        """
        df = []
        for year in (self.years):
            print(year)
            # Return data
            r = requests.get(self.base_url + self.endpoints['games'], params={'year': year})

            # Convert to dataframe
            df_year = pd.DataFrame.from_records(r.json())

            # Only retain useful fields, rename as necessary
            df_year = df_year[
                ['id', 'season', 'week', 'season_type', 'home_team', 'away_team', 'home_points', 'away_points']
            ].rename(columns={'id': 'game_id'})

            # Gather
            df.append(df_year)
        df = pd.concat(df).reset_index(drop=True)

        return df

    def download_stats(self, df_games: pd.DataFrame = None) -> pd.DataFrame:
        """
        Download stats for each game
        """
        if df_games is None:
            df_games = self.download_games()
        assert 'game_id' in df_games.columns
        print('stats')
        df_stats, not_working = [], {}
        for game_id in set(df_games['game_id']):
            params = {'gameId': game_id}
            r = requests.get(self.base_url + self.endpoints['stats'], params=params)
            if r.status_code != 200:
                continue
            if len(r.json()) == 0:
                continue
            try: 
                stats_by_team = r.json()[0]['teams']
                df_game = []
                for team in stats_by_team:
                    df_game_long = pd.DataFrame.from_records(team['stats'])
                    df_game_long['category'] = team['homeAway'] + '_' + df_game_long['category']
                    df_game.append(df_game_long)
                df_game = pd.concat(df_game)
                # Pivot
                df_game = pd.pivot_table(df_game, columns='category', values='stat', aggfunc='first').reset_index(drop=True)
                df_stats.append(df_game.assign(game_id=game_id))
            except:
                not_working[game_id] = r.json()
        df_stats = pd.concat(df_stats).reset_index(drop=True)
        
        return df_stats, not_working

# %%
downloader = DownloadCollegeFootballData()

# %%
params = {'gameId': 222430130}
r = requests.get('https://api.collegefootballdata.com/games/teams', params=params)

# %%
r.json()
# Out:
# []

# %%
import os
DATA_DIR = os.path.join(os.getcwd(), 'data')

df_stats = pd.read_csv(os.path.join(DATA_DIR, 'df_stats.csv'))
df_stats.shape
# Out:
# (12593, 71)

# %%
df_stats.isna().mean()
# Out:
# away_completionAttempts     0.002065
# away_defensiveTDs           0.736282
# away_firstDowns             0.002065
# away_fourthDownEff          0.002065
# away_fumblesLost            0.002065
# away_fumblesRecovered       0.000556
# away_interceptionTDs        0.446200
# away_interceptionYards      0.446200
# away_interceptions          0.002065
# away_kickReturnTDs          0.314460
# away_kickReturnYards        0.314460
# away_kickReturns            0.314460
# away_kickingPoints          0.037878
# away_netPassingYards        0.002065
# away_passesDeflected        0.736282
# away_passesIntercepted      0.446200
# away_passingTDs             0.005162
# away_possessionTime         0.005082
# away_puntReturnTDs          0.232987
# away_puntReturnYards        0.232987
# away_puntReturns            0.232987
# away_qbHurries              0.736282
# away_rushingAttempts        0.002065
# away_rushingTDs             0.002382
# away_rushingYards           0.002065
# away_sacks                  0.736282
# away_tackles                0.736282
# away_tacklesForLoss         0.736282
# away_thirdDownEff           0.002065
# away_totalFumbles           0.796871
# away_totalPenaltiesYards    0.002065
# away_totalYards             0.002065
# away_turnovers              0.002065
# away_yardsPerPass           0.002065
# away_yardsPerRushAttempt    0.002065
# game_id                     0.000000
# home_completionAttempts     0.001906
# home_defensiveTDs           0.735091
# home_firstDowns             0.001906
# home_fourthDownEff          0.001906
# home_fumblesLost            0.001906
# home_fumblesRecovered       0.000953
# home_interceptionTDs        0.382355
# home_interceptionYards      0.382355
# home_interceptions          0.001906
# home_kickReturnTDs          0.337886
# home_kickReturnYards        0.337886
# home_kickReturns            0.337886
# home_kickingPoints          0.013023
# home_netPassingYards        0.001906
# home_passesDeflected        0.735091
# home_passesIntercepted      0.382355
# home_passingTDs             0.004606
# home_possessionTime         0.003097
# home_puntReturnTDs          0.143492
# home_puntReturnYards        0.143492
# home_puntReturns            0.143492
# home_qbHurries              0.735091
# home_rushingAttempts        0.001906
# home_rushingTDs             0.002223
# home_rushingYards           0.001906
# home_sacks                  0.735091
# home_tackles                0.735091
# home_tacklesForLoss         0.735091
# home_thirdDownEff           0.001906
# home_totalFumbles           0.797030
# home_totalPenaltiesYards    0.001906
# home_totalYards             0.001906
# home_turnovers              0.001906
# home_yardsPerPass           0.001906
# home_yardsPerRushAttempt    0.001906
# dtype: float64

# %%
[
    'yardsPerRushAttempt', 
    'yardsPerPass', 
    'turnovers', 
    'totalYards', 
    'totalPenaltiesYards', 
    'thirdDownEff',
    'rushingYards',
    'rushingTDs',
    'rushingAttempts',
    'possessionTime',
    'passingTDs',
    'netPassingYards',
    'interceptions',
    'fumblesRecovered',
    'fumblesLost',
    'fourthDownEff',
    'firstDowns',
    'completionAttempts',
    'kickingPoints'
    ]
# Out:
#   away_completionAttempts  away_defensiveTDs  away_firstDowns  \
# 0                   11-19                NaN             18.0
# 1                   12-32                NaN              7.0
# 2                   23-30                NaN             26.0
# 3                    7-14                NaN              9.0
# 4                   16-29                NaN             17.0
#
#   away_fourthDownEff  away_fumblesLost  away_fumblesRecovered  \
# 0                0-0               0.0                    1.0
# 1                1-3               3.0                    2.0
# 2                1-1               2.0                    4.0
# 3                0-0               1.0                    0.0
# 4                1-3               2.0                    0.0
#
#    away_interceptionTDs  away_interceptionYards  away_interceptions  \
# 0                   0.0                     8.0                 0.0
# 1                   0.0                     1.0                 2.0
# 2                   0.0                     0.0                 1.0
# 3                   0.0                    27.0                 1.0
# 4                   NaN                     NaN                 2.0
#
#    away_kickReturnTDs  away_kickReturnYards  away_kickReturns  \
# 0                 0.0                 108.0               4.0
# 1                 0.0                 165.0              11.0
# 2                 NaN                   NaN               NaN
# 3                 NaN                   NaN               NaN
# 4                 NaN                   NaN               NaN
#
#    away_kickingPoints  away_netPassingYards  away_passesDeflected  \
# 0                 8.0                 122.0                   NaN
# 1                 0.0                  93.0                   NaN
# 2                 6.0                 249.0                   NaN
# 3                 NaN                  78.0                   NaN
# 4                 NaN                 261.0                   NaN
#
#    away_passesIntercepted  away_passingTDs away_possessionTime  \
# 0                     1.0              2.0               30:00
# 1                     1.0              0.0               20:30
# 2                     1.0              2.0               23:34
# 3                     1.0              0.0               16:11
# 4                     NaN              0.0               18:23
#
#    away_puntReturnTDs  away_puntReturnYards  away_puntReturns  away_qbHurries  \
# 0                 0.0                   1.0               1.0             NaN
# 1                 0.0                   1.0               1.0             NaN
# 2                 1.0                  94.0               5.0             NaN
# 3                 0.0                   6.0               3.0             NaN
# 4                 0.0                   8.0               2.0             NaN
#
#    away_rushingAttempts  away_rushingTDs  away_rushingYards  away_sacks  \
# 0                  41.0              1.0              199.0         NaN
# 1                  36.0              0.0               74.0         NaN
# 2                  54.0              3.0              186.0         NaN
# 3                  35.0              0.0               49.0         NaN
# 4                  39.0              0.0              121.0         NaN
#
#    away_tackles  away_tacklesForLoss away_thirdDownEff  away_totalFumbles  \
# 0           NaN                  NaN              4-11                NaN
# 1           NaN                  NaN              0-18                NaN
# 2           NaN                  NaN              5-15                NaN
# 3           NaN                  NaN              3-13                NaN
# 4           NaN                  NaN              8-16                NaN
#
#   away_totalPenaltiesYards  away_totalYards  away_turnovers  \
# 0                     5-40            321.0             0.0
# 1                     7-35            140.0             5.0
# 2                      0-0            421.0             3.0
# 3                      0-0            104.0             2.0
# 4                      0-0            356.0             4.0
#
#    away_yardsPerPass  away_yardsPerRushAttempt    game_id  \
# 0                6.4                       4.9  322732032
# 1                2.1                       2.1  302612483
# 2                7.8                       3.4  243040265
# 3                3.9                       1.4  243040276
# 4                8.1                       3.1  243040278
#
#   home_completionAttempts  home_defensiveTDs  home_firstDowns  \
# 0                   24-41                NaN             23.0
# 1                    9-20                NaN             24.0
# 2                   17-40                NaN             11.0
# 3                   19-35                NaN             21.0
# 4                   15-23                NaN             23.0
#
#   home_fourthDownEff  home_fumblesLost  home_fumblesRecovered  \
# 0                1-3               1.0                    0.0
# 1                2-3               2.0                    3.0
# 2                1-1               4.0                    2.0
# 3                2-3               0.0                    1.0
# 4                0-0               0.0                    2.0
#
#    home_interceptionTDs  home_interceptionYards  home_interceptions  \
# 0                   NaN                     NaN                 1.0
# 1                   0.0                    13.0                 1.0
# 2                   1.0                    28.0                 1.0
# 3                   1.0                    38.0                 1.0
# 4                   0.0                     5.0                 0.0
#
#    home_kickReturnTDs  home_kickReturnYards  home_kickReturns  \
# 0                 0.0                  66.0               5.0
# 1                 0.0                  25.0               1.0
# 2                 NaN                   NaN               NaN
# 3                 NaN                   NaN               NaN
# 4                 NaN                   NaN               NaN
#
#    home_kickingPoints  home_netPassingYards  home_passesDeflected  \
# 0                 7.0                 208.0                   NaN
# 1                15.0                 140.0                   NaN
# 2                 0.0                 195.0                   NaN
# 3                 8.0                 167.0                   NaN
# 4                 6.0                 203.0                   NaN
#
#    home_passesIntercepted  home_passingTDs home_possessionTime  \
# 0                     NaN              1.0               29:06
# 1                     2.0              4.0               16:10
# 2                     1.0              1.0               13:05
# 3                     1.0              1.0               20:12
# 4                     1.0              3.0               17:25
#
#    home_puntReturnTDs  home_puntReturnYards  home_puntReturns  home_qbHurries  \
# 0                 0.0                   2.0               1.0             NaN
# 1                 0.0                  68.0               7.0             NaN
# 2                 0.0                  19.0               3.0             NaN
# 3                 0.0                  31.0               4.0             NaN
# 4                 0.0                   0.0               1.0             NaN
#
#    home_rushingAttempts  home_rushingTDs  home_rushingYards  home_sacks  \
# 0                  39.0              0.0              127.0         NaN
# 1                  63.0              5.0              528.0         NaN
# 2                  25.0              0.0               -9.0         NaN
# 3                  42.0              0.0              176.0         NaN
# 4                  41.0              3.0              269.0         NaN
#
#    home_tackles  home_tacklesForLoss home_thirdDownEff  home_totalFumbles  \
# 0           NaN                  NaN              7-18                NaN
# 1           NaN                  NaN              8-16                NaN
# 2           NaN                  NaN              5-18                NaN
# 3           NaN                  NaN              5-16                NaN
# 4           NaN                  NaN              7-11                NaN
#
#   home_totalPenaltiesYards  home_totalYards  home_turnovers  \
# 0                     8-67            335.0             2.0
# 1                     7-50            668.0             3.0
# 2                      0-0            156.0             5.0
# 3                      0-0            331.0             1.0
# 4                      0-0            465.0             0.0
#
#    home_yardsPerPass  home_yardsPerRushAttempt
# 0                5.1                       3.3
# 1                7.0                       8.4
# 2                4.1                      -0.4
# 3                4.4                       4.2
# 4                8.5                       6.6

# %%
df_fails = pd.read_csv(os.path.join(DATA_DIR, 'df_failed_stats.csv'))
df_fails.shape
# Out:
# (2902, 2)

# %%
df_fails.head()
# Out:
#          error    game_id
# 0  No Response  213352483
# 1  No Response  213352509
# 2  No Response  223412390
# 3  No Response  223412426
# 4  No Response  213352653

# %%
set(df_fails['error'])
# Out:
# {"HTTPSConnectionPool(host='api.collegefootballdata.com', port=443): Max retries exceeded with url: /games/teams?gameId=302890059 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023E9A8A0400>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))",
#  "HTTPSConnectionPool(host='api.collegefootballdata.com', port=443): Max retries exceeded with url: /games/teams?gameId=400547963 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023E9D40F4E0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))",
#  'No Response'}

# %%
r = requests.get('https://api.collegefootballdata.com/rankings?year=2005')
r = r.json()

# %%
r[0]['polls'][0]
# Out:
# {'poll': 'Coaches Poll',
#  'ranks': [{'rank': 22,
#    'school': 'Michigan State',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 190},
#   {'rank': 17,
#    'school': 'Wisconsin',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 553},
#   {'rank': 13,
#    'school': 'Ohio State',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 742},
#   {'rank': 25,
#    'school': 'Minnesota',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 90},
#   {'rank': 1,
#    'school': 'USC',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 54,
#    'points': 1540},
#   {'rank': 9,
#    'school': 'UCLA',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 1053},
#   {'rank': 23,
#    'school': 'California',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 175},
#   {'rank': 16,
#    'school': 'Oregon',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 588},
#   {'rank': 20,
#    'school': 'West Virginia',
#    'conference': 'Big East',
#    'firstPlaceVotes': 0,
#    'points': 405},
#   {'rank': 14,
#    'school': 'Penn State',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 726},
#   {'rank': 2,
#    'school': 'Texas',
#    'conference': 'Big 12',
#    'firstPlaceVotes': 7,
#    'points': 1492},
#   {'rank': 8,
#    'school': 'Texas Tech',
#    'conference': 'Big 12',
#    'firstPlaceVotes': 0,
#    'points': 1079},
#   {'rank': 21,
#    'school': 'TCU',
#    'conference': 'Mountain West',
#    'firstPlaceVotes': 0,
#    'points': 221},
#   {'rank': 12,
#    'school': 'Notre Dame',
#    'conference': 'FBS Independents',
#    'firstPlaceVotes': 0,
#    'points': 846},
#   {'rank': 4,
#    'school': 'Georgia',
#    'conference': 'SEC',
#    'firstPlaceVotes': 0,
#    'points': 1361},
#   {'rank': 19,
#    'school': 'Florida',
#    'conference': 'SEC',
#    'firstPlaceVotes': 0,
#    'points': 450},
#   {'rank': 18,
#    'school': 'Tennessee',
#    'conference': 'SEC',
#    'firstPlaceVotes': 0,
#    'points': 543},
#   {'rank': 5,
#    'school': 'Alabama',
#    'conference': 'SEC',
#    'firstPlaceVotes': 0,
#    'points': 1255},
#   {'rank': 15,
#    'school': 'Auburn',
#    'conference': 'SEC',
#    'firstPlaceVotes': 0,
#    'points': 655},
#   {'rank': 7,
#    'school': 'LSU',
#    'conference': 'SEC',
#    'firstPlaceVotes': 0,
#    'points': 1154},
#   {'rank': 10,
#    'school': 'Florida State',
#    'conference': 'ACC',
#    'firstPlaceVotes': 0,
#    'points': 934},
#   {'rank': 11,
#    'school': 'Boston College',
#    'conference': 'ACC',
#    'firstPlaceVotes': 0,
#    'points': 859},
#   {'rank': 3,
#    'school': 'Virginia Tech',
#    'conference': 'ACC',
#    'firstPlaceVotes': 1,
#    'points': 1428},
#   {'rank': 6,
#    'school': 'Miami',
#    'conference': 'ACC',
#    'firstPlaceVotes': 0,
#    'points': 1218},
#   {'rank': 24,
#    'school': 'Virginia',
#    'conference': 'ACC',
#    'firstPlaceVotes': 0,
#    'points': 120}]}

# %%
df_ranks = pd.DataFrame.from_records(r[0]['polls'][0]['ranks'])
df_ranks.head()
# Out:
#    rank          school conference  firstPlaceVotes  points
# 0    22  Michigan State    Big Ten                0     190
# 1    17       Wisconsin    Big Ten                0     553
# 2    13      Ohio State    Big Ten                0     742
# 3    25       Minnesota    Big Ten                0      90
# 4     1             USC     Pac-10               54    1540

# %%
df_all_ranks = []
for week_record in r.json():
    week = week_record['week']
    for poll in week_record['polls']:
        poll_name = poll['poll']
        df_ranks = pd.DataFrame.from_records(poll['ranks'])
# Out:
# {'season': 2005,
#  'seasonType': 'regular',
#  'week': 8,
#  'polls': [{'poll': 'Coaches Poll',
#    'ranks': [{'rank': 22,
#      'school': 'Michigan State',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 190},
#     {'rank': 17,
#      'school': 'Wisconsin',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 553},
#     {'rank': 13,
#      'school': 'Ohio State',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 742},
#     {'rank': 25,
#      'school': 'Minnesota',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 90},
#     {'rank': 1,
#      'school': 'USC',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 54,
#      'points': 1540},
#     {'rank': 9,
#      'school': 'UCLA',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 0,
#      'points': 1053},
#     {'rank': 23,
#      'school': 'California',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 0,
#      'points': 175},
#     {'rank': 16,
#      'school': 'Oregon',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 0,
#      'points': 588},
#     {'rank': 20,
#      'school': 'West Virginia',
#      'conference': 'Big East',
#      'firstPlaceVotes': 0,
#      'points': 405},
#     {'rank': 14,
#      'school': 'Penn State',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 726},
#     {'rank': 2,
#      'school': 'Texas',
#      'conference': 'Big 12',
#      'firstPlaceVotes': 7,
#      'points': 1492},
#     {'rank': 8,
#      'school': 'Texas Tech',
#      'conference': 'Big 12',
#      'firstPlaceVotes': 0,
#      'points': 1079},
#     {'rank': 21,
#      'school': 'TCU',
#      'conference': 'Mountain West',
#      'firstPlaceVotes': 0,
#      'points': 221},
#     {'rank': 12,
#      'school': 'Notre Dame',
#      'conference': 'FBS Independents',
#      'firstPlaceVotes': 0,
#      'points': 846},
#     {'rank': 4,
#      'school': 'Georgia',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 1361},
#     {'rank': 19,
#      'school': 'Florida',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 450},
#     {'rank': 18,
#      'school': 'Tennessee',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 543},
#     {'rank': 5,
#      'school': 'Alabama',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 1255},
#     {'rank': 15,
#      'school': 'Auburn',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 655},
#     {'rank': 7,
#      'school': 'LSU',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 1154},
#     {'rank': 10,
#      'school': 'Florida State',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 934},
#     {'rank': 11,
#      'school': 'Boston College',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 859},
#     {'rank': 3,
#      'school': 'Virginia Tech',
#      'conference': 'ACC',
#      'firstPlaceVotes': 1,
#      'points': 1428},
#     {'rank': 6,
#      'school': 'Miami',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 1218},
#     {'rank': 24,
#      'school': 'Virginia',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 120}]},
#   {'poll': 'AP Top 25',
#    'ranks': [{'rank': 22,
#      'school': 'Michigan State',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 19,
#      'school': 'Wisconsin',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 14,
#      'school': 'Ohio State',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 1,
#      'school': 'USC',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 57,
#      'points': 0},
#     {'rank': 8,
#      'school': 'UCLA',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 25,
#      'school': 'California',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 15,
#      'school': 'Oregon',
#      'conference': 'Pac-10',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 20,
#      'school': 'West Virginia',
#      'conference': 'Big East',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 12,
#      'school': 'Penn State',
#      'conference': 'Big Ten',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 2,
#      'school': 'Texas',
#      'conference': 'Big 12',
#      'firstPlaceVotes': 8,
#      'points': 0},
#     {'rank': 10,
#      'school': 'Texas Tech',
#      'conference': 'Big 12',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 24,
#      'school': 'Fresno State',
#      'conference': 'Western Athletic',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 21,
#      'school': 'TCU',
#      'conference': 'Mountain West',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 9,
#      'school': 'Notre Dame',
#      'conference': 'FBS Independents',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 4,
#      'school': 'Georgia',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 18,
#      'school': 'Florida',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 17,
#      'school': 'Tennessee',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 5,
#      'school': 'Alabama',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 16,
#      'school': 'Auburn',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 7,
#      'school': 'LSU',
#      'conference': 'SEC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 11,
#      'school': 'Florida State',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 13,
#      'school': 'Boston College',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 3,
#      'school': 'Virginia Tech',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 6,
#      'school': 'Miami',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 0},
#     {'rank': 23,
#      'school': 'Virginia',
#      'conference': 'ACC',
#      'firstPlaceVotes': 0,
#      'points': 0}]}]}

# %%
df_rankings = pd.read_csv(os.path.join(os.getcwd(), 'data', 'df_rankings.csv'))
df_rankings.head()
# Out:
#   conference  firstPlaceVotes  points  rank          school       poll  week  \
# 0        ACC              NaN     NaN    17         Clemson  AP Top 25     1
# 1    Big Ten              NaN     NaN    25  Michigan State  AP Top 25     1
# 2    Big Ten              NaN     NaN    21        Illinois  AP Top 25     1
# 3    Big Ten              NaN     NaN     4       Wisconsin  AP Top 25     1
# 4    Big Ten              NaN     NaN     6        Michigan  AP Top 25     1
#
#    year
# 0  2000
# 1  2000
# 2  2000
# 3  2000
# 4  2000
